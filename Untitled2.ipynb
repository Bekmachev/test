# %% [markdown]
# <a href="https://colab.research.google.com/github/Bekmachev/test/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Загрузим датасет с сайта https://www.kaggle.com/datasets/jkraak/lego-sets-and-themes-*database*

# %%
import pandas as pd
data_lego = pd.read_csv('lego_sets_and_themes.csv')
data_lego.head(21503)
# Out:
#       set_number                        set_name  year_released  \
# 0          001-1                           Gears         1965.0
# 1          002-1  4.5V Samsonite Gears Motor Set         1965.0
# 2         1030-1  TECHNIC I: Simple Machines Set         1985.0
# 3         1038-1              ERBIE the Robo-Car         1985.0
# 4         1039-1            Manual Control Set 1         1986.0
# ...          ...                             ...            ...
# 21498    71039-4                    The Werewolf         2023.0
# 21499    71039-5                        She-Hulk         2023.0
# 21500    71039-6                         Hawkeye         2023.0
# 21501    71039-7                     Kate Bishop         2023.0
# 21502    71039-8                         Goliath         2023.0
#
#        number_of_parts                                          image_url  \
# 0                 43.0   https://cdn.rebrickable.com/media/sets/001-1.jpg
# ...

# %% [markdown]
# Далее применим функции DataFrame.info() и DataFrame.describe() к *data_moon_new*

# %%
data_lego.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21503 entries, 0 to 21502
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   set_number       21496 non-null  object
#  1   set_name         21496 non-null  object
#  2   year_released    21496 non-null  float64
#  3   number_of_parts  21496 non-null  float64
#  4   image_url        21496 non-null  object
#  5   theme_name       21503 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 1008.1+ KB

# %% [markdown]
# Применив фунцкию data_lego.info(), можно отметить, что датасет содержит 21503 строк и 6 столбцов, 4 из которых имеют наполнение данных типа object, а 2 - float64, причем практически все ячейки в датасет заполнены ненулевыми значениями

# %%
data_lego.describe()
# Out:
#        year_released  number_of_parts
# count   21496.000000     21496.000000
# mean     2007.579782       162.461760
# std        13.980685       417.187521
# min      1949.000000         0.000000
# 25%      2001.000000         4.000000
# 50%      2012.000000        32.000000
# 75%      2018.000000       142.000000
# max      2023.000000     11695.000000

# %% [markdown]
# Стобец year_released содержит значения года, когда выпущен набор Лего, можно отметить, что в датасете находятся данные с 1949 по 2023 года.
#
# Столбец number_of_parts содержит информацию о количестве деталей в наборе Лего, значения которых варьируются от 0 (скорей всего, это наборы по которым нет данных - требуется дополнительная проработка) до 11695 деталей, со средним значением - 162 детали.
